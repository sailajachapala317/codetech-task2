# %% [markdown]
# <a href="https://colab.research.google.com/github/sailajachapala317/codetech-task2/blob/main/Untitled44.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = sns.load_dataset('titanic')


print("Dataset Information:")
print(df.info())
print("\n")

print("Descriptive Statistics:")
print(df.describe())
print("\n")

print("Null Values:")
print(df.isnull().sum())
print("\n")

plt.figure(figsize=(12, 8))
df.hist(bins=20, edgecolor='black', figsize=(12, 8))
plt.suptitle('Feature Distributions', fontsize=16)
plt.show()

sns.pairplot(df, hue='survived', palette='Set1', dropna=True)
plt.suptitle('Pairwise Relationships (Colored by Survival)', fontsize=16)
plt.show()

plt.figure(figsize=(12, 8))
sns.boxplot(data=df.select_dtypes(include=np.number), width=0.5, palette='Set1')
plt.title('Boxplots for Numerical Features', fontsize=16)
plt.show()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

plt.figure(figsize=(8, 6))
sns.scatterplot(x='age', y='fare', hue='survived', data=df, palette='Set1')
plt.title('Age vs Fare (Colored by Survival)', fontsize=16)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()
plt.figure(figsize=(8, 6))
sns.countplot(x='class', hue='survived', data=df, palette='Set1')
plt.title('Survival Count by Class', fontsize=16)
plt.show()

plt.figure(figsize=(8, 6))
sns.kdeplot(df['age'].dropna(), shade=True, color='blue', label='Age Distribution')
plt.title('Age Distribution', fontsize=16)
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None
#
#
# Descriptive Statistics:
# ...
